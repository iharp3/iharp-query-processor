# %%
from multi_variables_executor import MultiGetRasterExecutor


# temporal range, resolution
start_datetime = "2020-01-01 00:00:00"
end_datetime = "2023-12-31 23:00:00"
temporal_resolution = "year"
# spatial range, resolution
min_lat = 59
max_lat = 84
min_lon = -74.0
max_lon = -10.0
spatial_resolution = 0.25
# aggregation method
aggregation = "max"

exec = MultiGetRasterExecutor(
    variables= ["2m_temperature", "snowfall", "surface_pressure"],
    start_datetime=start_datetime,
    end_datetime=end_datetime,
    temporal_resolution=temporal_resolution,
    min_lat=min_lat,
    max_lat=max_lat,
    min_lon=min_lon,
    max_lon=max_lon,
    spatial_resolution=spatial_resolution,
    aggregation=aggregation,
)

exec.execute()
# Out:
# local files: ['/data/agg/2m_temperature_GL_2015-2024_025year_max.nc']
# api: []
# local files: ['/data/agg/snowfall_GL_2015-2024_025year_max.nc']
# api: []
# local files: ['/data/agg/surface_pressure_GL_2015-2024_025year_max.nc']
# api: []
# <xarray.Dataset> Size: 1MB
# Dimensions:     (valid_time: 4, latitude: 101, longitude: 257)
# Coordinates:
#     number      int64 8B 0
#   * latitude    (latitude) float64 808B 84.0 83.75 83.5 ... 59.5 59.25 59.0
#   * longitude   (longitude) float64 2kB -74.0 -73.75 -73.5 ... -10.25 -10.0
#   * valid_time  (valid_time) datetime64[ns] 32B 2020-12-31 ... 2023-12-31
# Data variables:
#     t2m         (valid_time, latitude, longitude) float32 415kB 277.5 ... 289.9
#     sf          (valid_time, latitude, longitude) float32 415kB 0.001968 ... ...
#     sp          (valid_time, latitude, longitude) float32 415kB 1.043e+05 ......
# Attributes:
#     GRIB_centre:             ecmf
# ...
